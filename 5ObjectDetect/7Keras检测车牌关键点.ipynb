# %% [markdown]
# ### 设置超参数

# %%
IMG_SIZE = 224
BATCH_SIZE = 2
EPOCHS = 1000
NUM_KEYPOINTS = 4 * 2  # 4 pairs each having x and y coordinates

# %% [markdown]
# ### 准备数据集

# %%
# !unzip dataset.zip
# !rm -rf ./dataset/.DS_Store

# %% [markdown]
# ### 加载数据集，将数据集转换成如下格式的字典。
#
# ```json
# {
#   "image_path1" => [[
#     627.6153846153846,
#     872.6410256410256
#   ], ...],
#   "image_path2" => [...]
# }
# ```

# %%
import json
import pathlib

json_dict = {}
for p in pathlib.Path('./dataset').glob('*'):
  path = str(p)
  with open(path + '/1.json') as file:
    json_dict[path + '/1.jpeg'] = json.load(file)['shapes'][0]['points']

# %% [markdown]
# ### 根据 `key` 获取对应 `points`

# %%
from PIL import Image
from matplotlib import pyplot as plt

# Utility for reading an image and for getting its annotations.
def get_dog(key):  
  data = { 'joints': json_dict[key] }
  img_data = plt.imread(key)
  # If the image is RGBA convert it to RGB.
  if img_data.shape[-1] == 4:
    img_data = img_data.astype(np.uint8)
    img_data = Image.fromarray(img_data)
    img_data = np.array(img_data.convert("RGB"))
  data['img_data'] = img_data
  return data

# %% [markdown]
# ### 定义显示关键点方法

# %%
import numpy as np
from imgaug.augmentables.kps import KeypointsOnImage

def visualize_keypoints(images, keypoints):
    fig, axes = plt.subplots(nrows=len(images), ncols=2, figsize=(16, 12))
    [ax.axis("off") for ax in np.ravel(axes)]

    for (ax_orig, ax_all), image, current_keypoint in zip(axes, images, keypoints):
        ax_orig.imshow(image)
        ax_all.imshow(image)

        # If the keypoints were formed by `imgaug` then the coordinates need
        # to be iterated differently.
        if isinstance(current_keypoint, KeypointsOnImage):
            for idx, kp in enumerate(current_keypoint.keypoints):
                ax_all.scatter(
                    [kp.x], [kp.y], c='red', marker="x", s=50, linewidths=5
                )
        else:
            current_keypoint = np.array(current_keypoint)
            # Since the last entry is the visibility flag, we discard it.
            current_keypoint = current_keypoint[:, :2]
            for idx, (x, y) in enumerate(current_keypoint):
                ax_all.scatter([x], [y], c='red', marker="x", s=50, linewidths=5)

    plt.tight_layout(pad=2.0)
    plt.show()

# %% [markdown]
# ### 检查一下数据

# %%
# 选取两个样本检查
samples = list(json_dict.keys())
num_samples = 2
selected_samples = np.random.choice(samples, num_samples, replace=False)

images, keypoints = [], []

for sample in selected_samples:
    data = get_dog(sample)
    images.append(data["img_data"])
    keypoints.append(data["joints"])

visualize_keypoints(images, keypoints)

# %% [markdown]
# ### 构建数据生成器

# %%
from tensorflow import keras
from imgaug.augmentables.kps import Keypoint

class KeyPointsDataset(keras.utils.Sequence):
    def __init__(self, image_keys, aug, batch_size=BATCH_SIZE, train=True):
        self.image_keys = image_keys
        self.aug = aug
        self.batch_size = batch_size
        self.train = train
        self.on_epoch_end()

    def __len__(self):
        return len(self.image_keys) // self.batch_size

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.image_keys))
        if self.train:
            np.random.shuffle(self.indexes)

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size : (index + 1) * self.batch_size]
        image_keys_temp = [self.image_keys[k] for k in indexes]
        (images, keypoints) = self.__data_generation(image_keys_temp)

        return (images, keypoints)

    def __data_generation(self, image_keys_temp):
        batch_images = np.empty((self.batch_size, IMG_SIZE, IMG_SIZE, 3), dtype="int")
        batch_keypoints = np.empty(
            (self.batch_size, 1, 1, NUM_KEYPOINTS), dtype="float32"
        )

        for i, key in enumerate(image_keys_temp):
            data = get_dog(key)
            current_keypoint = np.array(data["joints"])[:, :2]
            kps = []

            # To apply our data augmentation pipeline, we first need to
            # form Keypoint objects with the original coordinates.
            for j in range(0, len(current_keypoint)):
                kps.append(Keypoint(x=current_keypoint[j][0], y=current_keypoint[j][1]))

            # We then project the original image and its keypoint coordinates.
            current_image = data["img_data"]
            kps_obj = KeypointsOnImage(kps, shape=current_image.shape)

            # Apply the augmentation pipeline.
            (new_image, new_kps_obj) = self.aug(image=current_image, keypoints=kps_obj)
            batch_images[i,] = new_image

            # Parse the coordinates from the new keypoint object.
            kp_temp = []
            for keypoint in new_kps_obj.keypoints:
                kp_temp.append(np.nan_to_num(keypoint.x))
                kp_temp.append(np.nan_to_num(keypoint.y))

            # More on why this reshaping later.
            batch_keypoints[i,] = np.array(kp_temp).reshape(1, 1, 4 * 2)

        # Scale the coordinates to [0, 1] range.
        batch_keypoints = batch_keypoints / IMG_SIZE

        return (batch_images, batch_keypoints)

# %%
import imgaug.augmenters as iaa

train_aug = iaa.Sequential(
    [
        iaa.Resize(IMG_SIZE, interpolation="linear"),
        iaa.Fliplr(0.3),
        # `Sometimes()` applies a function randomly to the inputs with
        # a given probability (0.3, in this case).
        iaa.Sometimes(0.3, iaa.Affine(rotate=10, scale=(0.5, 0.7))),
    ]
)

test_aug = iaa.Sequential([iaa.Resize(IMG_SIZE, interpolation="linear")])

# %% [markdown]
# ### 准备训练集和验证集

# %%
np.random.shuffle(samples)
train_keys, validation_keys = (
    samples[int(len(samples) * 0.15) :],
    samples[: int(len(samples) * 0.15)],
)

# %% [markdown]
# ### 检查训练集和验证集

# %%
train_dataset = KeyPointsDataset(train_keys, train_aug)
validation_dataset = KeyPointsDataset(validation_keys, test_aug, train=False)

print(f"Total batches in training set: {len(train_dataset)}")
print(f"Total batches in validation set: {len(validation_dataset)}")

sample_images, sample_keypoints = next(iter(train_dataset))

sample_keypoints = sample_keypoints[:4].reshape(-1, 4, 2) * IMG_SIZE
visualize_keypoints(sample_images[:4], sample_keypoints)
# Out:
# Total batches in training set: 1
# Total batches in validation set: 0

# %% [markdown]
# ### 构建模型

# %%
from tensorflow.keras import layers

def get_model():
    # Load the pre-trained weights of MobileNetV2 and freeze the weights
    backbone = keras.applications.MobileNetV2(
        weights="imagenet", include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    backbone.trainable = False

    inputs = layers.Input((IMG_SIZE, IMG_SIZE, 3))
    x = keras.applications.mobilenet_v2.preprocess_input(inputs)
    x = backbone(x)
    x = layers.Dropout(0.3)(x)
    x = layers.SeparableConv2D(NUM_KEYPOINTS, kernel_size=5, strides=1, activation="relu")(x)
    outputs = layers.SeparableConv2D(NUM_KEYPOINTS, kernel_size=3, strides=1, activation="sigmoid")(x)

    return keras.Model(inputs, outputs, name="keypoint_detector")

# %% [markdown]
# ### 生成模型

# %%
model = get_model()
model.compile(loss="mse", optimizer=keras.optimizers.Adam(1e-4))
get_model().summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step
# Model: "keypoint_detector"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  dropout_1 (Dropout)         (None, 7, 7, 1280)        0
#
#  separable_conv2d_2 (Separab  (None, 3, 3, 8)          42248
#  leConv2D)
#
#  separable_conv2d_3 (Separab  (None, 1, 1, 8)          144
#  leConv2D)
#
# =================================================================
# Total params: 2,300,376
# Trainable params: 42,392
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ### 预览模型架构

# %%
import tensorflow as tf

tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### 训练

# %%
model.fit(train_dataset, validation_data=train_dataset, epochs=EPOCHS)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 5s 5s/step - loss: 0.0299 - val_loss: 0.0296
# Epoch 2/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0215 - val_loss: 0.0294
# Epoch 3/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0296 - val_loss: 0.0183
# Epoch 4/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0300 - val_loss: 0.0289
# Epoch 5/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0301 - val_loss: 0.0212
# Epoch 6/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0296 - val_loss: 0.0285
# Epoch 7/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0285 - val_loss: 0.0287
# Epoch 8/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0288 - val_loss: 0.0206
# Epoch 9/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0279 - val_loss: 0.0191
# Epoch 10/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0280 - val_loss: 0.0199
# Epoch 11/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0108 - val_loss: 0.0274
# Epoch 12/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0276 - val_loss: 0.0113
# Epoch 13/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.0275 - val_loss: 0.0186
# Epoch 14/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0198 - val_loss: 0.0267
# Epoch 15/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0268 - val_loss: 0.0265
# Epoch 16/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0267 - val_loss: 0.0265
# Epoch 17/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0261 - val_loss: 0.0176
# Epoch 18/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0176 - val_loss: 0.0092
# Epoch 19/1000
# 1/1 [==============================] - 0s 485ms/step - loss: 0.0089 - val_loss: 0.0255
# Epoch 20/1000
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0254 - val_loss: 0.0184
# Epoch 21/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0095 - val_loss: 0.0164
# Epoch 22/1000
# 1/1 [==============================] - 1s 564ms/step - loss: 0.0250 - val_loss: 0.0106
# Epoch 23/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0080 - val_loss: 0.0165
# Epoch 24/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0159 - val_loss: 0.0243
# Epoch 25/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0179 - val_loss: 0.0154
# Epoch 26/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0095 - val_loss: 0.0247
# Epoch 27/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0159 - val_loss: 0.0152
# Epoch 28/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0246 - val_loss: 0.0071
# Epoch 29/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0094 - val_loss: 0.0242
# Epoch 30/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0159 - val_loss: 0.0232
# Epoch 31/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0143 - val_loss: 0.0170
# Epoch 32/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0229 - val_loss: 0.0237
# Epoch 33/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0237 - val_loss: 0.0235
# Epoch 34/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0226 - val_loss: 0.0161
# Epoch 35/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0220 - val_loss: 0.0230
# Epoch 36/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0079 - val_loss: 0.0219
# Epoch 37/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0167 - val_loss: 0.0217
# Epoch 38/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0229 - val_loss: 0.0158
# Epoch 39/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0214 - val_loss: 0.0133
# Epoch 40/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0146 - val_loss: 0.0229
# Epoch 41/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0159 - val_loss: 0.0209
# Epoch 42/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0218 - val_loss: 0.0215
# Epoch 43/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0147 - val_loss: 0.0205
# Epoch 44/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0213 - val_loss: 0.0204
# Epoch 45/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0215 - val_loss: 0.0208
# Epoch 46/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0152 - val_loss: 0.0139
# Epoch 47/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0203 - val_loss: 0.0134
# Epoch 48/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0151 - val_loss: 0.0134
# Epoch 49/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0205 - val_loss: 0.0194
# Epoch 50/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0195 - val_loss: 0.0135
# Epoch 51/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0137 - val_loss: 0.0142
# Epoch 52/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0202 - val_loss: 0.0188
# Epoch 53/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0122 - val_loss: 0.0134
# Epoch 54/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 55/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0188 - val_loss: 0.0113
# Epoch 56/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0182 - val_loss: 0.0123
# Epoch 57/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0180 - val_loss: 0.0123
# Epoch 58/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0119 - val_loss: 0.0112
# Epoch 59/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0186 - val_loss: 0.0075
# Epoch 60/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0117 - val_loss: 0.0113
# Epoch 61/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0121 - val_loss: 0.0109
# Epoch 62/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0119 - val_loss: 0.0117
# Epoch 63/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0167 - val_loss: 0.0172
# Epoch 64/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0166 - val_loss: 0.0165
# Epoch 65/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0112 - val_loss: 0.0059
# Epoch 66/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0171 - val_loss: 0.0166
# Epoch 67/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0171 - val_loss: 0.0073
# Epoch 68/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 69/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 70/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0108 - val_loss: 0.0100
# Epoch 71/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0112 - val_loss: 0.0048
# Epoch 72/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0064 - val_loss: 0.0152
# Epoch 73/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0062 - val_loss: 0.0155
# Epoch 74/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0100 - val_loss: 0.0150
# Epoch 75/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 76/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0158 - val_loss: 0.0151
# Epoch 77/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0148 - val_loss: 0.0061
# Epoch 78/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0152 - val_loss: 0.0145
# Epoch 79/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0105 - val_loss: 0.0102
# Epoch 80/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0106 - val_loss: 0.0107
# Epoch 81/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0145 - val_loss: 0.0142
# Epoch 82/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0148 - val_loss: 0.0089
# Epoch 83/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0147 - val_loss: 0.0100
# Epoch 84/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0087 - val_loss: 0.0058
# Epoch 85/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0053 - val_loss: 0.0088
# Epoch 86/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0092 - val_loss: 0.0083
# Epoch 87/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0135 - val_loss: 0.0086
# Epoch 88/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0138 - val_loss: 0.0097
# Epoch 89/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0135 - val_loss: 0.0132
# Epoch 90/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0136 - val_loss: 0.0131
# Epoch 91/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0094 - val_loss: 0.0129
# Epoch 92/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0130 - val_loss: 0.0082
# Epoch 93/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0130 - val_loss: 0.0126
# Epoch 94/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0045 - val_loss: 0.0125
# Epoch 95/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0035 - val_loss: 0.0085
# Epoch 96/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0129 - val_loss: 0.0078
# Epoch 97/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0078 - val_loss: 0.0084
# Epoch 98/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0123 - val_loss: 0.0121
# Epoch 99/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0126 - val_loss: 0.0120
# Epoch 100/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0121 - val_loss: 0.0084
# Epoch 101/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0075 - val_loss: 0.0118
# Epoch 102/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0119 - val_loss: 0.0080
# Epoch 103/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0079 - val_loss: 0.0115
# Epoch 104/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0082 - val_loss: 0.0031
# Epoch 105/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 106/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0113 - val_loss: 0.0086
# Epoch 107/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0115 - val_loss: 0.0109
# Epoch 108/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0115 - val_loss: 0.0078
# Epoch 109/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0106 - val_loss: 0.0069
# Epoch 110/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0044 - val_loss: 0.0072
# Epoch 111/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0068 - val_loss: 0.0104
# Epoch 112/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 113/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 114/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0063 - val_loss: 0.0101
# Epoch 115/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0070 - val_loss: 0.0100
# Epoch 116/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 117/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0075 - val_loss: 0.0069
# Epoch 118/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 119/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0034 - val_loss: 0.0093
# Epoch 120/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 121/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0104 - val_loss: 0.0069
# Epoch 122/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0095 - val_loss: 0.0093
# Epoch 123/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0075 - val_loss: 0.0030
# Epoch 124/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0092 - val_loss: 0.0089
# Epoch 125/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 126/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0071 - val_loss: 0.0088
# Epoch 127/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 128/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 129/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0085 - val_loss: 0.0040
# Epoch 130/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 131/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0041 - val_loss: 0.0083
# Epoch 132/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0058 - val_loss: 0.0080
# Epoch 133/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 134/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0055 - val_loss: 0.0078
# Epoch 135/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 136/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 137/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0080 - val_loss: 0.0050
# Epoch 138/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0035 - val_loss: 0.0078
# Epoch 139/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0031 - val_loss: 0.0074
# Epoch 140/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0061 - val_loss: 0.0048
# Epoch 141/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0077 - val_loss: 0.0072
# Epoch 142/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0053 - val_loss: 0.0073
# Epoch 143/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 144/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 145/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 146/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0044 - val_loss: 0.0068
# Epoch 147/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 148/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0068 - val_loss: 0.0041
# Epoch 149/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0067 - val_loss: 0.0052
# Epoch 150/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0066 - val_loss: 0.0050
# Epoch 151/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0045 - val_loss: 0.0067
# Epoch 152/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 153/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 154/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 155/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0068 - val_loss: 0.0059
# Epoch 156/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 157/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 158/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0036 - val_loss: 0.0056
# Epoch 159/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 160/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 161/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 162/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 163/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0036 - val_loss: 0.0052
# Epoch 164/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 165/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 166/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0039 - val_loss: 0.0051
# Epoch 167/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0056 - val_loss: 0.0037
# Epoch 168/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0036 - val_loss: 0.0050
# Epoch 169/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 170/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 171/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 172/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 173/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 174/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 175/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 176/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 177/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0044 - val_loss: 0.0027
# Epoch 178/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 179/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 180/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 181/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 182/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 183/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 184/1000
# 1/1 [==============================] - 1s 593ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 185/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 186/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 187/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 188/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 189/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 190/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 191/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 192/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 193/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 194/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 195/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 196/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 197/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 198/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 199/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 200/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 201/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 202/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 203/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 204/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 205/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 206/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 207/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 208/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 209/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 210/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 211/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 212/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 213/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 214/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 215/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 216/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 217/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 218/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 219/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 220/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 221/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 222/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 223/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 224/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 225/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 226/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 227/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 228/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 229/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 230/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 231/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 232/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 233/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 234/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 235/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 236/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 237/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 238/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 239/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 240/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 241/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 242/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 243/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 244/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 245/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 246/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 247/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 248/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 249/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 250/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 251/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 252/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 253/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 254/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 255/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 256/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 257/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 258/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 259/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 260/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 261/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 262/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 263/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 264/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 265/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 266/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 267/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 268/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 269/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 270/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 271/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 272/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 273/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 274/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0013 - val_loss: 9.4313e-04
# Epoch 275/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 276/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 277/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0014 - val_loss: 9.8368e-04
# Epoch 278/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 279/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 280/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 281/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 9.6929e-04 - val_loss: 0.0011
# Epoch 282/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 283/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 284/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 285/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 286/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 287/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 9.3771e-04 - val_loss: 9.9641e-04
# Epoch 288/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0010 - val_loss: 9.4951e-04
# Epoch 289/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 290/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 291/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 292/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 9.6323e-04 - val_loss: 0.0010
# Epoch 293/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0012 - val_loss: 9.1307e-04
# Epoch 294/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0010 - val_loss: 9.0495e-04
# Epoch 295/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0010 - val_loss: 8.9700e-04
# Epoch 296/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0010 - val_loss: 9.0667e-04
# Epoch 297/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0012 - val_loss: 8.6040e-04
# Epoch 298/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 9.2650e-04 - val_loss: 8.6071e-04
# Epoch 299/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0012 - val_loss: 8.6073e-04
# Epoch 300/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 9.8517e-04 - val_loss: 8.6295e-04
# Epoch 301/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0011 - val_loss: 9.7956e-04
# Epoch 302/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0013 - val_loss: 9.2499e-04
# Epoch 303/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 304/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 9.5046e-04 - val_loss: 8.5236e-04
# Epoch 305/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 9.1317e-04 - val_loss: 8.1350e-04
# Epoch 306/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 9.7010e-04 - val_loss: 8.2409e-04
# Epoch 307/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0010 - val_loss: 7.2590e-04
# Epoch 308/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 9.4168e-04 - val_loss: 7.8888e-04
# Epoch 309/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 8.1771e-04 - val_loss: 7.1234e-04
# Epoch 310/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 9.1176e-04 - val_loss: 9.2393e-04
# Epoch 311/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0011 - val_loss: 7.9635e-04
# Epoch 312/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 8.7319e-04 - val_loss: 7.0950e-04
# Epoch 313/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 7.9073e-04 - val_loss: 9.9372e-04
# Epoch 314/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 8.1737e-04 - val_loss: 7.8917e-04
# Epoch 315/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 8.0754e-04 - val_loss: 7.9481e-04
# Epoch 316/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 9.3192e-04 - val_loss: 9.2582e-04
# Epoch 317/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 8.5473e-04 - val_loss: 6.6887e-04
# Epoch 318/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 6.8585e-04 - val_loss: 7.4963e-04
# Epoch 319/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0011 - val_loss: 6.0834e-04
# Epoch 320/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 9.0173e-04 - val_loss: 0.0010
# Epoch 321/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 322/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 6.6965e-04 - val_loss: 7.8024e-04
# Epoch 323/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 7.8245e-04 - val_loss: 7.7383e-04
# Epoch 324/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 7.5477e-04 - val_loss: 7.6010e-04
# Epoch 325/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 6.6568e-04 - val_loss: 5.4406e-04
# Epoch 326/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0011 - val_loss: 5.3535e-04
# Epoch 327/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 5.7563e-04 - val_loss: 5.2661e-04
# Epoch 328/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 6.4400e-04 - val_loss: 5.1742e-04
# Epoch 329/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 6.2035e-04 - val_loss: 7.5300e-04
# Epoch 330/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 9.7479e-04 - val_loss: 4.9990e-04
# Epoch 331/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 9.0801e-04 - val_loss: 6.1994e-04
# Epoch 332/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0014 - val_loss: 6.7408e-04
# Epoch 333/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 5.8089e-04 - val_loss: 0.0010
# Epoch 334/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 8.3668e-04 - val_loss: 0.0012
# Epoch 335/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 6.7757e-04 - val_loss: 7.2547e-04
# Epoch 336/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0015 - val_loss: 4.5805e-04
# Epoch 337/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 8.4237e-04 - val_loss: 7.0851e-04
# Epoch 338/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 7.3589e-04 - val_loss: 4.5073e-04
# Epoch 339/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0014 - val_loss: 4.5182e-04
# Epoch 340/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 6.1631e-04 - val_loss: 6.2141e-04
# Epoch 341/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 8.0679e-04 - val_loss: 6.6944e-04
# Epoch 342/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 8.3875e-04 - val_loss: 8.6757e-04
# Epoch 343/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 7.3334e-04 - val_loss: 6.2779e-04
# Epoch 344/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 5.1593e-04 - val_loss: 5.7623e-04
# Epoch 345/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 7.6181e-04 - val_loss: 5.1821e-04
# Epoch 346/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 5.6688e-04 - val_loss: 5.8891e-04
# Epoch 347/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 4.9688e-04 - val_loss: 4.4706e-04
# Epoch 348/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 7.3438e-04 - val_loss: 5.3233e-04
# Epoch 349/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 5.8423e-04 - val_loss: 5.6003e-04
# Epoch 350/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 8.3092e-04 - val_loss: 4.3755e-04
# Epoch 351/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0010 - val_loss: 5.0819e-04
# Epoch 352/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 5.3653e-04 - val_loss: 5.8678e-04
# Epoch 353/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 9.7777e-04 - val_loss: 4.3931e-04
# Epoch 354/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 5.0660e-04 - val_loss: 4.4170e-04
# Epoch 355/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 5.3090e-04 - val_loss: 5.7558e-04
# Epoch 356/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 6.3492e-04 - val_loss: 4.4358e-04
# Epoch 357/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 7.4001e-04 - val_loss: 4.4489e-04
# Epoch 358/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 5.1465e-04 - val_loss: 5.8162e-04
# Epoch 359/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 6.7543e-04 - val_loss: 5.7584e-04
# Epoch 360/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 7.8033e-04 - val_loss: 5.6471e-04
# Epoch 361/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 4.2344e-04 - val_loss: 8.3192e-04
# Epoch 362/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 6.1475e-04 - val_loss: 5.4063e-04
# Epoch 363/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 7.8703e-04 - val_loss: 3.8602e-04
# Epoch 364/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 6.1357e-04 - val_loss: 7.3912e-04
# Epoch 365/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 5.3414e-04 - val_loss: 3.7156e-04
# Epoch 366/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 8.8501e-04 - val_loss: 3.6745e-04
# Epoch 367/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 4.3400e-04 - val_loss: 5.4361e-04
# Epoch 368/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 6.7074e-04 - val_loss: 5.0963e-04
# Epoch 369/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 5.8935e-04 - val_loss: 5.3528e-04
# Epoch 370/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 6.1246e-04 - val_loss: 3.3838e-04
# Epoch 371/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 4.6486e-04 - val_loss: 5.3066e-04
# Epoch 372/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 6.1841e-04 - val_loss: 4.8983e-04
# Epoch 373/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 9.5102e-04 - val_loss: 7.3030e-04
# Epoch 374/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 6.0136e-04 - val_loss: 3.8239e-04
# Epoch 375/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 6.8766e-04 - val_loss: 5.1815e-04
# Epoch 376/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 5.6980e-04 - val_loss: 7.1146e-04
# Epoch 377/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 5.8337e-04 - val_loss: 5.0029e-04
# Epoch 378/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 5.9429e-04 - val_loss: 6.9814e-04
# Epoch 379/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 3.7115e-04 - val_loss: 4.9888e-04
# Epoch 380/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 3.9222e-04 - val_loss: 5.9237e-04
# Epoch 381/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 5.5430e-04 - val_loss: 4.9789e-04
# Epoch 382/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 9.2542e-04 - val_loss: 5.5939e-04
# Epoch 383/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 7.2053e-04 - val_loss: 3.8644e-04
# Epoch 384/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 4.3391e-04 - val_loss: 5.2871e-04
# Epoch 385/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 6.8480e-04 - val_loss: 4.9568e-04
# Epoch 386/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 4.1317e-04 - val_loss: 4.7151e-04
# Epoch 387/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 3.8502e-04 - val_loss: 4.8909e-04
# Epoch 388/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 5.1544e-04 - val_loss: 2.6796e-04
# Epoch 389/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 7.2132e-04 - val_loss: 4.9221e-04
# Epoch 390/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 3.6787e-04 - val_loss: 2.5757e-04
# Epoch 391/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 8.5640e-04 - val_loss: 4.8385e-04
# Epoch 392/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 6.9415e-04 - val_loss: 2.5472e-04
# Epoch 393/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 6.4570e-04 - val_loss: 3.9933e-04
# Epoch 394/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 2.8487e-04 - val_loss: 2.5866e-04
# Epoch 395/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 5.8924e-04 - val_loss: 6.1291e-04
# Epoch 396/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 3.7479e-04 - val_loss: 3.2980e-04
# Epoch 397/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 2.8850e-04 - val_loss: 2.6662e-04
# Epoch 398/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 5.7539e-04 - val_loss: 7.1832e-04
# Epoch 399/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 9.6519e-04 - val_loss: 2.5255e-04
# Epoch 400/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 7.0407e-04 - val_loss: 2.3744e-04
# Epoch 401/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 5.9417e-04 - val_loss: 4.6974e-04
# Epoch 402/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 6.5561e-04 - val_loss: 6.5356e-04
# Epoch 403/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0011 - val_loss: 2.1920e-04
# Epoch 404/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 2.4989e-04 - val_loss: 2.1883e-04
# Epoch 405/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 3.1058e-04 - val_loss: 3.0204e-04
# Epoch 406/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 4.0860e-04 - val_loss: 3.2892e-04
# Epoch 407/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 9.4860e-04 - val_loss: 4.3667e-04
# Epoch 408/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 6.1398e-04 - val_loss: 3.5585e-04
# Epoch 409/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 5.1285e-04 - val_loss: 6.8550e-04
# Epoch 410/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 4.2514e-04 - val_loss: 4.4061e-04
# Epoch 411/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 4.4214e-04 - val_loss: 5.6523e-04
# Epoch 412/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 3.8472e-04 - val_loss: 2.0629e-04
# Epoch 413/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 3.3102e-04 - val_loss: 4.3499e-04
# Epoch 414/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 2.6660e-04 - val_loss: 3.6478e-04
# Epoch 415/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 7.1911e-04 - val_loss: 7.4030e-04
# Epoch 416/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 4.4057e-04 - val_loss: 7.1728e-04
# Epoch 417/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 5.7945e-04 - val_loss: 4.3003e-04
# Epoch 418/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 4.0955e-04 - val_loss: 6.6609e-04
# Epoch 419/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 2.6992e-04 - val_loss: 1.9371e-04
# Epoch 420/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 2.9464e-04 - val_loss: 1.9079e-04
# Epoch 421/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 4.4276e-04 - val_loss: 2.3939e-04
# Epoch 422/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 2.2394e-04 - val_loss: 4.3865e-04
# Epoch 423/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 5.6666e-04 - val_loss: 7.5110e-04
# Epoch 424/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 2.1666e-04 - val_loss: 6.6466e-04
# Epoch 425/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 2.7624e-04 - val_loss: 3.7725e-04
# Epoch 426/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 2.7147e-04 - val_loss: 4.2762e-04
# Epoch 427/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 3.6540e-04 - val_loss: 1.5965e-04
# Epoch 428/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 4.7885e-04 - val_loss: 4.2762e-04
# Epoch 429/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0011 - val_loss: 6.2791e-04
# Epoch 430/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 6.1571e-04 - val_loss: 5.4776e-04
# Epoch 431/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 2.2507e-04 - val_loss: 4.3227e-04
# Epoch 432/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 2.8207e-04 - val_loss: 4.3747e-04
# Epoch 433/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 2.3650e-04 - val_loss: 5.5502e-04
# Epoch 434/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 2.4732e-04 - val_loss: 4.4607e-04
# Epoch 435/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 2.0176e-04 - val_loss: 3.4586e-04
# Epoch 436/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 2.5149e-04 - val_loss: 2.5826e-04
# Epoch 437/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 7.0160e-04 - val_loss: 6.9400e-04
# Epoch 438/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 4.3432e-04 - val_loss: 3.4903e-04
# Epoch 439/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 8.1945e-04 - val_loss: 5.4222e-04
# Epoch 440/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 2.6889e-04 - val_loss: 4.5140e-04
# Epoch 441/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 2.8599e-04 - val_loss: 1.3018e-04
# Epoch 442/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 7.8356e-04 - val_loss: 2.8771e-04
# Epoch 443/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0010 - val_loss: 6.8653e-04
# Epoch 444/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 5.6202e-04 - val_loss: 3.3009e-04
# Epoch 445/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 8.7444e-04 - val_loss: 4.1612e-04
# Epoch 446/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 4.1901e-04 - val_loss: 1.4730e-04
# Epoch 447/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 5.4612e-04 - val_loss: 1.4983e-04
# Epoch 448/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 7.0312e-04 - val_loss: 6.1635e-04
# Epoch 449/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 6.8280e-04 - val_loss: 1.5576e-04
# Epoch 450/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 5.5540e-04 - val_loss: 3.9992e-04
# Epoch 451/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 7.4201e-04 - val_loss: 3.5771e-04
# Epoch 452/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 3.5464e-04 - val_loss: 3.0907e-04
# Epoch 453/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 1.8475e-04 - val_loss: 3.7793e-04
# Epoch 454/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 3.5826e-04 - val_loss: 3.8094e-04
# Epoch 455/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 2.5888e-04 - val_loss: 1.8725e-04
# Epoch 456/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 7.2478e-04 - val_loss: 2.5316e-04
# Epoch 457/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 3.2158e-04 - val_loss: 2.7590e-04
# Epoch 458/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 2.6115e-04 - val_loss: 4.0638e-04
# Epoch 459/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 5.0727e-04 - val_loss: 2.9487e-04
# Epoch 460/1000
# ...
# Epoch 850/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 1.6967e-04 - val_loss: 1.1470e-04
# Epoch 851/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 4.1152e-04 - val_loss: 5.2185e-05
# Epoch 852/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 2.8696e-04 - val_loss: 1.0488e-04
# Epoch 853/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 2.3442e-04 - val_loss: 9.7162e-05
# Epoch 854/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 1.7968e-04 - val_loss: 6.5708e-05
# Epoch 855/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 2.3242e-04 - val_loss: 2.1524e-05
# Epoch 856/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 1.0328e-04 - val_loss: 7.6361e-05
# Epoch 857/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 3.4907e-04 - val_loss: 9.4867e-05
# Epoch 858/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 1.0968e-04 - val_loss: 9.4059e-05
# Epoch 859/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 1.2977e-04 - val_loss: 9.5634e-05
# Epoch 860/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 2.0163e-04 - val_loss: 9.8881e-05
# Epoch 861/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 1.8996e-04 - val_loss: 7.4446e-05
# Epoch 862/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 1.7383e-04 - val_loss: 1.0738e-04
# Epoch 863/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 1.4974e-04 - val_loss: 1.1407e-04
# Epoch 864/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 2.0734e-04 - val_loss: 1.2932e-04
# Epoch 865/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 3.3979e-04 - val_loss: 9.6601e-05
# Epoch 866/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 1.9925e-04 - val_loss: 9.2083e-05
# Epoch 867/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 5.1239e-05 - val_loss: 2.0483e-05
# Epoch 868/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 2.6757e-04 - val_loss: 5.9116e-05
# Epoch 869/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 2.5303e-04 - val_loss: 5.5257e-05
# Epoch 870/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 2.9483e-04 - val_loss: 6.2340e-05
# Epoch 871/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 1.4240e-04 - val_loss: 1.7558e-04
# Epoch 872/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 1.7540e-04 - val_loss: 1.5342e-04
# Epoch 873/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 1.6320e-04 - val_loss: 3.8924e-05
# Epoch 874/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 1.2658e-04 - val_loss: 1.1375e-04
# Epoch 875/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 6.8050e-05 - val_loss: 1.2359e-04
# Epoch 876/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 2.6487e-04 - val_loss: 4.8985e-05
# Epoch 877/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 8.4028e-05 - val_loss: 9.6157e-05
# Epoch 878/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 2.1869e-04 - val_loss: 5.6208e-05
# Epoch 879/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 1.7365e-04 - val_loss: 8.9833e-05
# Epoch 880/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 1.8801e-04 - val_loss: 4.4505e-05
# Epoch 881/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 2.2589e-04 - val_loss: 2.0078e-04
# Epoch 882/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 2.4791e-04 - val_loss: 1.2437e-04
# Epoch 883/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 2.9805e-04 - val_loss: 2.2131e-04
# Epoch 884/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 3.0364e-04 - val_loss: 1.9031e-04
# Epoch 885/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 1.6313e-04 - val_loss: 5.6181e-05
# Epoch 886/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 2.4172e-04 - val_loss: 2.5464e-05
# Epoch 887/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 6.4978e-04 - val_loss: 1.8068e-05
# Epoch 888/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 1.3308e-04 - val_loss: 8.7486e-05
# Epoch 889/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 1.7866e-04 - val_loss: 2.2001e-04
# Epoch 890/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 1.4964e-04 - val_loss: 8.5377e-05
# Epoch 891/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 3.8993e-05 - val_loss: 1.3497e-05
# Epoch 892/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 2.3268e-04 - val_loss: 1.2850e-04
# Epoch 893/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 1.5520e-04 - val_loss: 8.2403e-05
# Epoch 894/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 3.8691e-04 - val_loss: 1.3369e-05
# Epoch 895/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 2.6444e-04 - val_loss: 1.2991e-04
# Epoch 896/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.4523e-04 - val_loss: 7.9888e-05
# Epoch 897/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 1.9818e-04 - val_loss: 1.3731e-05
# Epoch 898/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 1.4857e-04 - val_loss: 1.4933e-05
# Epoch 899/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 8.2754e-05 - val_loss: 9.5148e-05
# Epoch 900/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 2.0013e-04 - val_loss: 8.5338e-05
# Epoch 901/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 2.7926e-04 - val_loss: 1.3898e-04
# Epoch 902/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 7.4472e-05 - val_loss: 1.0763e-04
# Epoch 903/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 1.2030e-04 - val_loss: 5.8883e-05
# Epoch 904/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 1.6657e-04 - val_loss: 9.2395e-05
# Epoch 905/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 4.0520e-05 - val_loss: 8.0475e-05
# Epoch 906/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.7931e-04 - val_loss: 2.7822e-05
# Epoch 907/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 2.4688e-04 - val_loss: 8.5072e-05
# Epoch 908/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 2.0313e-04 - val_loss: 1.0088e-04
# Epoch 909/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 2.0093e-04 - val_loss: 2.2255e-05
# Epoch 910/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 5.0582e-05 - val_loss: 8.0359e-05
# Epoch 911/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 1.8728e-04 - val_loss: 6.4624e-05
# Epoch 912/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 2.7132e-04 - val_loss: 8.0255e-05
# Epoch 913/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 2.0402e-04 - val_loss: 1.0747e-04
# Epoch 914/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 1.5509e-04 - val_loss: 8.2366e-05
# Epoch 915/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 9.7334e-05 - val_loss: 1.0315e-04
# Epoch 916/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 1.6727e-04 - val_loss: 8.5987e-05
# Epoch 917/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 1.6501e-04 - val_loss: 3.5369e-05
# Epoch 918/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 1.2743e-04 - val_loss: 1.0661e-04
# Epoch 919/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 1.0094e-04 - val_loss: 7.8823e-05
# Epoch 920/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 1.6085e-04 - val_loss: 1.8967e-04
# Epoch 921/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.7718e-04 - val_loss: 1.6575e-05
# Epoch 922/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 1.3003e-04 - val_loss: 7.8860e-05
# Epoch 923/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 1.5372e-04 - val_loss: 1.6537e-05
# Epoch 924/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 1.1562e-04 - val_loss: 1.5829e-05
# Epoch 925/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 1.4808e-04 - val_loss: 7.6239e-05
# Epoch 926/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 5.0866e-05 - val_loss: 1.2588e-04
# Epoch 927/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 2.1371e-04 - val_loss: 8.3614e-05
# Epoch 928/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 5.4160e-05 - val_loss: 1.7791e-05
# Epoch 929/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 9.7190e-05 - val_loss: 8.6994e-05
# Epoch 930/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 1.2795e-04 - val_loss: 1.9149e-05
# Epoch 931/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 2.6903e-04 - val_loss: 1.6345e-04
# Epoch 932/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.4733e-04 - val_loss: 1.8064e-05
# Epoch 933/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 2.4179e-04 - val_loss: 1.7304e-05
# Epoch 934/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 1.9560e-04 - val_loss: 8.6291e-05
# Epoch 935/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 3.7685e-04 - val_loss: 2.0196e-04
# Epoch 936/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 1.8195e-04 - val_loss: 1.0821e-04
# Epoch 937/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 1.5564e-04 - val_loss: 9.7496e-05
# Epoch 938/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 1.7819e-04 - val_loss: 1.0378e-04
# Epoch 939/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 1.4432e-04 - val_loss: 1.6566e-04
# Epoch 940/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 1.9115e-04 - val_loss: 1.3999e-04
# Epoch 941/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 1.7670e-04 - val_loss: 7.6024e-05
# Epoch 942/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 2.7766e-04 - val_loss: 2.4992e-04
# Epoch 943/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 1.1314e-04 - val_loss: 5.1618e-05
# Epoch 944/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 2.5323e-04 - val_loss: 8.1750e-05
# Epoch 945/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 4.1829e-05 - val_loss: 7.2167e-05
# Epoch 946/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 8.3781e-05 - val_loss: 1.7294e-04
# Epoch 947/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 1.2429e-04 - val_loss: 5.8308e-05
# Epoch 948/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 1.4906e-04 - val_loss: 2.3090e-04
# Epoch 949/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 1.9782e-04 - val_loss: 1.2652e-04
# Epoch 950/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 2.1009e-04 - val_loss: 6.7057e-05
# Epoch 951/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 2.3460e-04 - val_loss: 1.1859e-04
# Epoch 952/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 1.0955e-04 - val_loss: 1.1649e-04
# Epoch 953/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 2.0504e-04 - val_loss: 1.3864e-04
# Epoch 954/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 1.0868e-04 - val_loss: 2.0591e-05
# Epoch 955/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 1.1558e-04 - val_loss: 9.3563e-05
# Epoch 956/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 1.8634e-04 - val_loss: 3.0564e-05
# Epoch 957/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 1.6394e-04 - val_loss: 9.1494e-05
# Epoch 958/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 1.9887e-04 - val_loss: 3.8971e-05
# Epoch 959/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 4.1530e-05 - val_loss: 9.5037e-05
# Epoch 960/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 1.3269e-04 - val_loss: 3.3848e-05
# Epoch 961/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 1.8970e-04 - val_loss: 2.7508e-05
# Epoch 962/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 9.8355e-05 - val_loss: 1.9576e-05
# Epoch 963/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 2.2278e-04 - val_loss: 1.7029e-05
# Epoch 964/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 1.8534e-04 - val_loss: 4.9125e-05
# Epoch 965/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 1.3907e-04 - val_loss: 1.0625e-04
# Epoch 966/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 1.8210e-04 - val_loss: 2.4631e-05
# Epoch 967/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 1.6160e-04 - val_loss: 7.8865e-05
# Epoch 968/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 3.8433e-05 - val_loss: 2.1801e-05
# Epoch 969/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 1.2733e-04 - val_loss: 1.0490e-04
# Epoch 970/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 1.5576e-04 - val_loss: 2.7091e-05
# Epoch 971/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 5.1238e-05 - val_loss: 7.8859e-05
# Epoch 972/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 2.1157e-04 - val_loss: 1.2580e-04
# Epoch 973/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 1.1772e-04 - val_loss: 8.2442e-05
# Epoch 974/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 1.1803e-04 - val_loss: 8.7033e-05
# Epoch 975/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 1.9347e-04 - val_loss: 7.9238e-05
# Epoch 976/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 1.8290e-04 - val_loss: 7.5193e-05
# Epoch 977/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 1.9507e-04 - val_loss: 3.4218e-05
# Epoch 978/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 2.0559e-04 - val_loss: 1.4126e-04
# Epoch 979/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 2.0685e-04 - val_loss: 2.6996e-05
# Epoch 980/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 9.4082e-05 - val_loss: 6.5918e-05
# Epoch 981/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 1.8891e-04 - val_loss: 1.0537e-04
# Epoch 982/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 5.4581e-05 - val_loss: 9.5159e-05
# Epoch 983/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 1.1945e-04 - val_loss: 9.7136e-05
# Epoch 984/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 2.7515e-04 - val_loss: 7.9993e-05
# Epoch 985/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.0440e-04 - val_loss: 5.2931e-05
# Epoch 986/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 3.8731e-04 - val_loss: 6.9129e-05
# Epoch 987/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 2.0214e-04 - val_loss: 1.1778e-04
# Epoch 988/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 4.0504e-05 - val_loss: 4.2988e-05
# Epoch 989/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 3.4840e-04 - val_loss: 4.0746e-05
# Epoch 990/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 2.2956e-04 - val_loss: 7.1580e-05
# Epoch 991/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 8.1546e-05 - val_loss: 9.8919e-05
# Epoch 992/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 1.8835e-04 - val_loss: 1.8113e-05
# Epoch 993/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 8.0265e-05 - val_loss: 9.3944e-05
# Epoch 994/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 2.3142e-04 - val_loss: 8.1489e-05
# Epoch 995/1000

# %% [markdown]
# ### 显示训练结果

# %%
sample_val_images, sample_val_keypoints = next(iter(train_dataset))
sample_val_images = sample_val_images[:2]
sample_val_keypoints = sample_val_keypoints[:4].reshape(-1, 4, 2) * IMG_SIZE
predictions = model.predict(sample_val_images).reshape(-1, 4, 2) * IMG_SIZE

# Ground-truth
visualize_keypoints(sample_val_images, sample_val_keypoints)

# Predictions
visualize_keypoints(sample_val_images, predictions)
