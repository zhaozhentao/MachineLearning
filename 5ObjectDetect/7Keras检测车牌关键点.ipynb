# %% [markdown]
# ### 设置超参数

# %%
IMG_SIZE = 625
BATCH_SIZE = 2
EPOCHS = 1000
NUM_KEYPOINTS = 4 * 2  # 4 pairs each having x and y coordinates

# %% [markdown]
# ### 准备数据集

# %%
# !unzip -oq dataset.zip
# !rm -rf ./dataset/.DS_Store
# !rm -rf __MACOSX

# %% [markdown]
# ### 加载数据集，将数据集转换成如下格式的字典。
#
# ```json
# {
#   "image_path1" => [[
#     627.6153846153846,
#     872.6410256410256
#   ], ...],
#   "image_path2" => [...]
# }
# ```

# %%
import json
import pathlib

json_dict = {}
for p in pathlib.Path('./dataset').glob('*'):
  plate = p.name  
  path = str(p)
  with open(f"{path}/{plate}.json") as file:
    json_dict[f"{path}/{plate}.jpg"] = json.load(file)['shapes'][0]['points']

# %% [markdown]
# ### 根据 `key` 获取对应 `points`

# %%
from PIL import Image
from matplotlib import pyplot as plt

# Utility for reading an image and for getting its annotations.
def get_dog(key):  
  data = { 'joints': json_dict[key] }
  img_data = plt.imread(key)
  # If the image is RGBA convert it to RGB.
  if img_data.shape[-1] == 4:
    img_data = img_data.astype(np.uint8)
    img_data = Image.fromarray(img_data)
    img_data = np.array(img_data.convert("RGB"))
  data['img_data'] = img_data
  return data

# %% [markdown]
# ### 定义显示关键点方法

# %%
import numpy as np
from imgaug.augmentables.kps import KeypointsOnImage

def visualize_keypoints(images, keypoints):
    fig, axes = plt.subplots(nrows=len(images), ncols=2, figsize=(16, 12))
    [ax.axis("off") for ax in np.ravel(axes)]

    for (ax_orig, ax_all), image, current_keypoint in zip(axes, images, keypoints):
        ax_orig.imshow(image)
        ax_all.imshow(image)

        # If the keypoints were formed by `imgaug` then the coordinates need
        # to be iterated differently.
        if isinstance(current_keypoint, KeypointsOnImage):
            for idx, kp in enumerate(current_keypoint.keypoints):
                ax_all.scatter(
                    [kp.x], [kp.y], c='red', marker="x", s=50, linewidths=5
                )
        else:
            current_keypoint = np.array(current_keypoint)
            # Since the last entry is the visibility flag, we discard it.
            current_keypoint = current_keypoint[:, :2]
            for idx, (x, y) in enumerate(current_keypoint):
                ax_all.scatter([x], [y], c='red', marker="x", s=50, linewidths=5)

    plt.tight_layout(pad=2.0)
    plt.show()

# %% [markdown]
# ### 检查一下数据

# %%
# 选取两个样本检查
samples = list(json_dict.keys())
num_samples = 2
selected_samples = np.random.choice(samples, num_samples, replace=False)

images, keypoints = [], []

for sample in selected_samples:
    data = get_dog(sample)
    images.append(data["img_data"])
    keypoints.append(data["joints"])

visualize_keypoints(images, keypoints)

# %% [markdown]
# ### 构建数据生成器

# %%
from tensorflow import keras
from imgaug.augmentables.kps import Keypoint

class KeyPointsDataset(keras.utils.Sequence):
    def __init__(self, image_keys, aug, batch_size=BATCH_SIZE, train=True):
        self.image_keys = image_keys
        self.aug = aug
        self.batch_size = batch_size
        self.train = train
        self.on_epoch_end()

    def __len__(self):
        return len(self.image_keys) // self.batch_size

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.image_keys))
        if self.train:
            np.random.shuffle(self.indexes)

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size : (index + 1) * self.batch_size]
        image_keys_temp = [self.image_keys[k] for k in indexes]
        (images, keypoints) = self.__data_generation(image_keys_temp)

        return (images, keypoints)

    def __data_generation(self, image_keys_temp):
        batch_images = np.empty((self.batch_size, IMG_SIZE, IMG_SIZE, 3), dtype="int")
        batch_keypoints = np.empty(
            (self.batch_size, 1, 1, NUM_KEYPOINTS), dtype="float32"
        )

        for i, key in enumerate(image_keys_temp):
            data = get_dog(key)
            current_keypoint = np.array(data["joints"])[:, :2]
            kps = []

            # To apply our data augmentation pipeline, we first need to
            # form Keypoint objects with the original coordinates.
            for j in range(0, len(current_keypoint)):
                kps.append(Keypoint(x=current_keypoint[j][0], y=current_keypoint[j][1]))

            # We then project the original image and its keypoint coordinates.
            current_image = data["img_data"]
            kps_obj = KeypointsOnImage(kps, shape=current_image.shape)

            # Apply the augmentation pipeline.
            (new_image, new_kps_obj) = self.aug(image=current_image, keypoints=kps_obj)
            batch_images[i,] = new_image

            # Parse the coordinates from the new keypoint object.
            kp_temp = []
            for keypoint in new_kps_obj.keypoints:
                kp_temp.append(np.nan_to_num(keypoint.x))
                kp_temp.append(np.nan_to_num(keypoint.y))

            # More on why this reshaping later.
            batch_keypoints[i,] = np.array(kp_temp).reshape(1, 1, 4 * 2)

        # Scale the coordinates to [0, 1] range.
        batch_keypoints = batch_keypoints / IMG_SIZE

        return (batch_images, batch_keypoints)

# %%
import imgaug.augmenters as iaa

train_aug = iaa.Sequential([iaa.Resize(IMG_SIZE, interpolation="linear")])
test_aug = iaa.Sequential([iaa.Resize(IMG_SIZE, interpolation="linear")])

# %% [markdown]
# ### 准备训练集和验证集

# %%
np.random.shuffle(samples)
train_keys, validation_keys = (
    samples[int(len(samples) * 0.15) :],
    samples[: int(len(samples) * 0.15)],
)

# %% [markdown]
# ### 检查训练集和验证集

# %%
train_dataset = KeyPointsDataset(train_keys, train_aug)
validation_dataset = KeyPointsDataset(validation_keys, test_aug, train=False)

print(f"Total batches in training set: {len(train_dataset)}")
print(f"Total batches in validation set: {len(validation_dataset)}")

sample_images, sample_keypoints = next(iter(train_dataset))

sample_keypoints = sample_keypoints[:4].reshape(-1, 4, 2) * IMG_SIZE
visualize_keypoints(sample_images[:4], sample_keypoints)
# Out:
# Total batches in training set: 7
# Total batches in validation set: 1

# %% [markdown]
# ### 构建模型

# %%
import tensorflow as tf

def get_model():
  inputs = keras.layers.Input((IMG_SIZE, IMG_SIZE, 3))
  x = tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), strides=1, padding='same', activation='relu')(inputs)
  x = tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same', strides=2)(x)
  x = tf.keras.layers.Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='same', activation='relu')(x)
  x = tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same', strides=2)(x)  
  x = tf.keras.layers.Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='same', activation='relu')(x)
  x = tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same', strides=2)(x)    
  x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same', activation='relu')(x)
  x = tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same', strides=2)(x)    
  x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same', activation='relu')(x)
  x = tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same', strides=2)(x)       
  x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same', activation='relu')(x)
  x = tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same', strides=2)(x)         
  x = tf.keras.layers.SeparableConv2D(NUM_KEYPOINTS, kernel_size=5, strides=1, activation="relu")(x)
  x = tf.keras.layers.SeparableConv2D(NUM_KEYPOINTS, kernel_size=3, strides=1, activation="relu")(x)   
  x = tf.keras.layers.SeparableConv2D(NUM_KEYPOINTS, kernel_size=3, strides=1, activation="sigmoid")(x) 
  x = tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same', strides=2)(x) 
  return keras.models.Model(inputs=inputs, outputs=x)

# %% [markdown]
# ### 生成模型

# %%
model = get_model()
model.compile(loss="mse", optimizer=keras.optimizers.Adam(1e-4))
get_model().summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 625, 625, 3)]     0
#
#  conv2d_6 (Conv2D)           (None, 625, 625, 128)     3584
#
#  max_pooling2d_7 (MaxPooling  (None, 313, 313, 128)    0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 313, 313, 96)      110688
#
#  max_pooling2d_8 (MaxPooling  (None, 157, 157, 96)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 157, 157, 96)      83040
#
#  max_pooling2d_9 (MaxPooling  (None, 79, 79, 96)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 79, 79, 64)        55360
#
#  max_pooling2d_10 (MaxPoolin  (None, 40, 40, 64)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 40, 40, 64)        36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 20, 20, 64)        36928
#
#  max_pooling2d_12 (MaxPoolin  (None, 10, 10, 64)       0
#  g2D)
#
#  separable_conv2d_3 (Separab  (None, 6, 6, 8)          2120
#  leConv2D)
#
#  separable_conv2d_4 (Separab  (None, 4, 4, 8)          144
#  leConv2D)
#
#  separable_conv2d_5 (Separab  (None, 2, 2, 8)          144
#  leConv2D)
#
#  max_pooling2d_13 (MaxPoolin  (None, 1, 1, 8)          0
#  g2D)
#
# =================================================================
# Total params: 328,936
# Trainable params: 328,936
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 预览模型架构

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# ### 训练

# %%
model.fit(train_dataset, validation_data=train_dataset, epochs=EPOCHS)
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 15s 2s/step - loss: 0.0205 - val_loss: 0.0201
# Epoch 2/1000
# 7/7 [==============================] - 13s 2s/step - loss: 0.0201 - val_loss: 0.0199
# Epoch 3/1000
# 7/7 [==============================] - 13s 2s/step - loss: 0.0199 - val_loss: 0.0198
# Epoch 4/1000
# 7/7 [==============================] - 14s 2s/step - loss: 0.0197 - val_loss: 0.0196
# Epoch 5/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0195 - val_loss: 0.0194
# Epoch 6/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0193 - val_loss: 0.0192
# Epoch 7/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0191 - val_loss: 0.0190
# Epoch 8/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0189 - val_loss: 0.0187
# Epoch 9/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0186 - val_loss: 0.0184
# Epoch 10/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0183 - val_loss: 0.0182
# Epoch 11/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0181 - val_loss: 0.0181
# Epoch 12/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0181 - val_loss: 0.0178
# Epoch 13/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0178 - val_loss: 0.0177
# Epoch 14/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0178 - val_loss: 0.0174
# Epoch 15/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0175 - val_loss: 0.0172
# Epoch 16/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0174 - val_loss: 0.0171
# Epoch 17/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0172 - val_loss: 0.0171
# Epoch 18/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0170 - val_loss: 0.0167
# Epoch 19/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0166 - val_loss: 0.0164
# Epoch 20/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0164 - val_loss: 0.0161
# Epoch 21/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0161 - val_loss: 0.0164
# Epoch 22/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0164 - val_loss: 0.0163
# Epoch 23/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0166 - val_loss: 0.0164
# Epoch 24/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0163 - val_loss: 0.0161
# Epoch 25/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0161 - val_loss: 0.0160
# Epoch 26/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0157 - val_loss: 0.0155
# Epoch 27/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0154 - val_loss: 0.0150
# Epoch 28/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0150 - val_loss: 0.0147
# Epoch 29/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0147 - val_loss: 0.0146
# Epoch 30/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0145 - val_loss: 0.0145
# Epoch 31/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0146 - val_loss: 0.0144
# Epoch 32/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0143 - val_loss: 0.0142
# Epoch 33/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0144 - val_loss: 0.0141
# Epoch 34/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0141 - val_loss: 0.0140
# Epoch 35/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0141 - val_loss: 0.0139
# Epoch 36/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0138 - val_loss: 0.0137
# Epoch 37/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0140 - val_loss: 0.0135
# Epoch 38/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0136 - val_loss: 0.0136
# Epoch 39/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0138 - val_loss: 0.0136
# Epoch 40/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0135 - val_loss: 0.0132
# Epoch 41/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0134 - val_loss: 0.0131
# Epoch 42/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0132 - val_loss: 0.0133
# Epoch 43/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0133 - val_loss: 0.0131
# Epoch 44/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0133 - val_loss: 0.0130
# Epoch 45/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0131 - val_loss: 0.0132
# Epoch 46/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0135 - val_loss: 0.0133
# Epoch 47/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0136 - val_loss: 0.0134
# Epoch 48/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0133 - val_loss: 0.0129
# Epoch 49/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0130 - val_loss: 0.0128
# Epoch 50/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0129 - val_loss: 0.0129
# Epoch 51/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0137 - val_loss: 0.0129
# Epoch 52/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0142 - val_loss: 0.0136
# Epoch 53/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0142 - val_loss: 0.0143
# Epoch 54/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0141 - val_loss: 0.0135
# Epoch 55/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0134 - val_loss: 0.0129
# Epoch 56/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0128 - val_loss: 0.0126
# Epoch 57/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0125 - val_loss: 0.0122
# Epoch 58/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 59/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0122 - val_loss: 0.0122
# Epoch 60/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0123 - val_loss: 0.0120
# Epoch 61/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 62/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0119 - val_loss: 0.0118
# Epoch 63/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0119 - val_loss: 0.0118
# Epoch 64/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0120 - val_loss: 0.0120
# Epoch 65/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 66/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0119 - val_loss: 0.0116
# Epoch 67/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0117 - val_loss: 0.0116
# Epoch 68/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 69/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0119 - val_loss: 0.0115
# Epoch 70/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0115 - val_loss: 0.0114
# Epoch 71/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0115 - val_loss: 0.0114
# Epoch 72/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0116 - val_loss: 0.0114
# Epoch 73/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0115 - val_loss: 0.0115
# Epoch 74/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0117 - val_loss: 0.0119
# Epoch 75/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0119 - val_loss: 0.0114
# Epoch 76/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0118 - val_loss: 0.0116
# Epoch 77/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0118 - val_loss: 0.0114
# Epoch 78/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0115 - val_loss: 0.0114
# Epoch 79/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0114 - val_loss: 0.0111
# Epoch 80/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0110 - val_loss: 0.0106
# Epoch 81/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0111 - val_loss: 0.0117
# Epoch 82/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0129 - val_loss: 0.0117
# Epoch 83/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0119 - val_loss: 0.0113
# Epoch 84/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0114 - val_loss: 0.0106
# Epoch 85/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0108 - val_loss: 0.0101
# Epoch 86/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 87/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0097 - val_loss: 0.0100
# Epoch 88/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0100 - val_loss: 0.0110
# Epoch 89/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 90/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 91/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0106 - val_loss: 0.0095
# Epoch 92/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 93/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0100 - val_loss: 0.0096
# Epoch 94/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0095 - val_loss: 0.0090
# Epoch 95/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 96/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0098 - val_loss: 0.0092
# Epoch 97/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0096 - val_loss: 0.0093
# Epoch 98/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0094 - val_loss: 0.0088
# Epoch 99/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 100/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0088 - val_loss: 0.0084
# Epoch 101/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 102/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 103/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 104/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 105/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 106/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 107/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0081 - val_loss: 0.0078
# Epoch 108/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 109/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 110/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0077 - val_loss: 0.0077
# Epoch 111/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0078 - val_loss: 0.0077
# Epoch 112/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0078 - val_loss: 0.0077
# Epoch 113/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 114/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0081 - val_loss: 0.0075
# Epoch 115/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 116/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 117/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 118/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 119/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 120/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 121/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 122/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0075 - val_loss: 0.0076
# Epoch 123/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 124/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 125/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 126/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 127/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 128/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 129/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 130/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 131/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 132/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 133/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 134/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 135/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0072 - val_loss: 0.0069
# Epoch 136/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0069 - val_loss: 0.0069
# Epoch 137/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 138/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 139/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 140/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 141/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0073 - val_loss: 0.0070
# Epoch 142/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0074 - val_loss: 0.0068
# Epoch 143/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 144/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 145/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 146/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 147/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 148/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 149/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 150/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 151/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 152/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 153/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 154/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 155/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 156/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 157/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 158/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 159/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 160/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 161/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 162/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 163/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 164/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0065 - val_loss: 0.0059
# Epoch 165/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 166/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 167/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 168/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 169/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0060 - val_loss: 0.0055
# Epoch 170/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 171/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 172/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 173/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 174/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 175/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 176/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0061 - val_loss: 0.0056
# Epoch 177/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 178/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 179/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 180/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 181/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 182/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 183/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 184/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 185/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 186/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 187/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 188/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 189/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 190/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 191/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 192/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 193/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 194/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 195/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 196/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 197/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 198/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 199/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 200/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 201/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 202/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 203/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 204/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 205/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 206/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0040 - val_loss: 0.0035
# Epoch 207/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 208/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 209/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 210/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 211/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 212/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 213/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 214/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 215/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 216/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 217/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 218/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 219/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 220/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 221/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 222/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 223/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 224/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 225/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 226/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 227/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 228/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 229/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 230/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 231/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 232/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 233/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 234/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 235/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 236/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 237/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 238/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 239/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 240/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 241/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 242/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 243/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 244/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 245/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 246/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 247/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 248/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 249/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 250/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 251/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 252/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 253/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 254/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 255/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 256/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 257/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 258/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 259/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 260/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 261/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 262/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 263/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 264/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 265/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 266/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 267/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 268/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 269/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 270/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 271/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 272/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 273/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 274/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 275/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 276/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 277/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 278/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 279/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 280/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 281/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 282/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 283/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 284/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 285/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 286/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 287/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 288/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 289/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 290/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 291/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 292/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 293/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 294/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 295/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 296/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 297/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 298/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 299/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 300/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 301/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 302/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 303/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 304/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 305/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 306/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 307/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 308/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 309/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 310/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 311/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 312/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 313/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 314/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 315/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 316/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 317/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 318/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 319/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 320/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 321/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 322/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 323/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 324/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 325/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 326/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 327/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 328/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 329/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 330/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 331/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 332/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 333/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 334/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 335/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 336/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 337/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 338/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 339/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 340/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 341/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 342/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 343/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 344/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 345/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 346/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 347/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 348/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 349/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 350/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 351/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 352/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 353/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 354/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 355/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 356/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 357/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 358/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 359/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 360/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 361/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 362/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 363/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 364/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 365/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 366/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 367/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 368/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 369/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 370/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 371/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 372/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 373/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 374/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 375/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 376/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 377/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 378/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 379/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 380/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 381/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 382/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 383/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 384/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 385/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 386/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 387/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 388/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 389/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 390/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 391/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 392/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 393/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 394/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 395/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 396/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 397/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 398/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 399/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 400/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 401/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 402/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 403/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 404/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 405/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 406/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 407/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 408/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 409/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 410/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 411/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 412/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 413/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 414/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 415/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 416/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 417/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 418/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 419/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 420/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 421/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 422/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 423/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 424/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 425/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 426/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 427/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 428/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 429/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 430/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 431/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 432/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 433/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 434/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 435/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 436/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 437/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 438/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 439/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 440/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0010 - val_loss: 9.9298e-04
# Epoch 441/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 442/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0010 - val_loss: 9.3460e-04
# Epoch 443/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0010 - val_loss: 9.8682e-04
# Epoch 444/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.9272e-04 - val_loss: 9.7424e-04
# Epoch 445/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.8001e-04 - val_loss: 9.4334e-04
# Epoch 446/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.8313e-04 - val_loss: 9.5044e-04
# Epoch 447/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.7411e-04 - val_loss: 0.0010
# Epoch 448/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.9275e-04 - val_loss: 9.6792e-04
# Epoch 449/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 450/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 451/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 9.5177e-04
# Epoch 452/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0011 - val_loss: 9.3829e-04
# Epoch 453/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0010 - val_loss: 9.8074e-04
# Epoch 454/1000
# 7/7 [==============================] - 12s 2s/step - loss: 0.0010 - val_loss: 9.1567e-04
# Epoch 455/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.5692e-04 - val_loss: 9.2771e-04
# Epoch 456/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.6104e-04 - val_loss: 9.0657e-04
# Epoch 457/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.3678e-04 - val_loss: 8.6688e-04
# Epoch 458/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.6811e-04 - val_loss: 8.6743e-04
# Epoch 459/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.7940e-04 - val_loss: 8.4616e-04
# Epoch 460/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.6063e-04 - val_loss: 8.4349e-04
# Epoch 461/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.4307e-04 - val_loss: 8.3076e-04
# Epoch 462/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.3760e-04 - val_loss: 8.2035e-04
# Epoch 463/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.2717e-04 - val_loss: 8.0994e-04
# Epoch 464/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.1139e-04 - val_loss: 8.0207e-04
# Epoch 465/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.0435e-04 - val_loss: 7.9269e-04
# Epoch 466/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.9606e-04 - val_loss: 7.9930e-04
# Epoch 467/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.9760e-04 - val_loss: 7.8413e-04
# Epoch 468/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.9333e-04 - val_loss: 7.9082e-04
# Epoch 469/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.1068e-04 - val_loss: 7.8937e-04
# Epoch 470/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.0744e-04 - val_loss: 8.2751e-04
# Epoch 471/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.9663e-04 - val_loss: 8.0931e-04
# Epoch 472/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.1302e-04 - val_loss: 8.1015e-04
# Epoch 473/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.8816e-04 - val_loss: 8.6841e-04
# Epoch 474/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.0724e-04 - val_loss: 8.6274e-04
# Epoch 475/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.9412e-04 - val_loss: 8.1204e-04
# Epoch 476/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.2376e-04 - val_loss: 7.9931e-04
# Epoch 477/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.4160e-04 - val_loss: 7.8813e-04
# Epoch 478/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.3701e-04 - val_loss: 7.8552e-04
# Epoch 479/1000
# ...
# Epoch 853/1000
# 7/7 [==============================] - 12s 2s/step - loss: 6.4355e-05 - val_loss: 3.6377e-05
# Epoch 854/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.5900e-05 - val_loss: 4.6352e-05
# Epoch 855/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.9929e-05 - val_loss: 3.5935e-05
# Epoch 856/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.6708e-05 - val_loss: 5.2189e-05
# Epoch 857/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.0018e-05 - val_loss: 4.3907e-05
# Epoch 858/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.1413e-04 - val_loss: 4.2355e-05
# Epoch 859/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.0048e-05 - val_loss: 7.3385e-05
# Epoch 860/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.2138e-04 - val_loss: 1.0429e-04
# Epoch 861/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.1126e-04 - val_loss: 1.0458e-04
# Epoch 862/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.6932e-04 - val_loss: 1.4786e-04
# Epoch 863/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.4710e-04 - val_loss: 1.2809e-04
# Epoch 864/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.8474e-04 - val_loss: 2.2675e-04
# Epoch 865/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.7205e-04 - val_loss: 1.2307e-04
# Epoch 866/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.8523e-04 - val_loss: 1.5506e-04
# Epoch 867/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.8274e-04 - val_loss: 1.0348e-04
# Epoch 868/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.6431e-04 - val_loss: 6.9772e-05
# Epoch 869/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.2691e-04 - val_loss: 8.9384e-05
# Epoch 870/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0605e-04 - val_loss: 9.7580e-05
# Epoch 871/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.1644e-04 - val_loss: 6.5691e-05
# Epoch 872/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.1331e-04 - val_loss: 6.9020e-05
# Epoch 873/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.4333e-04 - val_loss: 4.4270e-05
# Epoch 874/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0035e-04 - val_loss: 4.4164e-05
# Epoch 875/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0536e-04 - val_loss: 6.8205e-05
# Epoch 876/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.9963e-05 - val_loss: 1.3648e-04
# Epoch 877/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.0893e-04 - val_loss: 5.5916e-04
# Epoch 878/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.7635e-04 - val_loss: 5.4238e-04
# Epoch 879/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.3570e-04 - val_loss: 4.6316e-04
# Epoch 880/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.4303e-04 - val_loss: 4.0672e-04
# Epoch 881/1000
# 7/7 [==============================] - 12s 2s/step - loss: 6.8407e-04 - val_loss: 3.8603e-04
# Epoch 882/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.5290e-04 - val_loss: 3.2390e-04
# Epoch 883/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.1235e-04 - val_loss: 3.5436e-04
# Epoch 884/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.3233e-04 - val_loss: 4.5154e-04
# Epoch 885/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.6498e-04 - val_loss: 2.9000e-04
# Epoch 886/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.1539e-04 - val_loss: 2.6303e-04
# Epoch 887/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.8502e-04 - val_loss: 2.7938e-04
# Epoch 888/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.1157e-04 - val_loss: 2.7070e-04
# Epoch 889/1000
# 7/7 [==============================] - 12s 2s/step - loss: 6.0442e-04 - val_loss: 3.2121e-04
# Epoch 890/1000
# 7/7 [==============================] - 12s 2s/step - loss: 6.1370e-04 - val_loss: 3.7929e-04
# Epoch 891/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.2208e-04 - val_loss: 2.7795e-04
# Epoch 892/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.2142e-04 - val_loss: 2.7710e-04
# Epoch 893/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.2767e-04 - val_loss: 3.6510e-04
# Epoch 894/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.7312e-04 - val_loss: 3.1837e-04
# Epoch 895/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.5934e-04 - val_loss: 2.2021e-04
# Epoch 896/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.7308e-04 - val_loss: 1.8478e-04
# Epoch 897/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.5240e-04 - val_loss: 1.5042e-04
# Epoch 898/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.7780e-04 - val_loss: 1.4314e-04
# Epoch 899/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.3620e-04 - val_loss: 7.7935e-05
# Epoch 900/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0353e-04 - val_loss: 1.2054e-04
# Epoch 901/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.3725e-04 - val_loss: 1.0639e-04
# Epoch 902/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.1616e-04 - val_loss: 7.6917e-05
# Epoch 903/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.3039e-05 - val_loss: 5.7793e-05
# Epoch 904/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.3502e-05 - val_loss: 4.8440e-05
# Epoch 905/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.7583e-05 - val_loss: 3.8257e-05
# Epoch 906/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.9765e-05 - val_loss: 3.7733e-05
# Epoch 907/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.0263e-05 - val_loss: 3.3933e-05
# Epoch 908/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.0784e-05 - val_loss: 3.6417e-05
# Epoch 909/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.4275e-05 - val_loss: 3.8635e-05
# Epoch 910/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.5824e-05 - val_loss: 2.7823e-05
# Epoch 911/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.6324e-05 - val_loss: 3.6278e-05
# Epoch 912/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.8144e-05 - val_loss: 4.5516e-05
# Epoch 913/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.4839e-05 - val_loss: 3.6891e-05
# Epoch 914/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.6488e-05 - val_loss: 3.0074e-05
# Epoch 915/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.4532e-05 - val_loss: 2.9694e-05
# Epoch 916/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.4430e-05 - val_loss: 2.5746e-05
# Epoch 917/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.7175e-05 - val_loss: 2.5000e-05
# Epoch 918/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.6300e-05 - val_loss: 2.8809e-05
# Epoch 919/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.6792e-05 - val_loss: 1.9918e-05
# Epoch 920/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.9037e-05 - val_loss: 2.4171e-05
# Epoch 921/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.9242e-05 - val_loss: 2.5926e-05
# Epoch 922/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.4817e-05 - val_loss: 3.0982e-05
# Epoch 923/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.1141e-05 - val_loss: 2.8811e-05
# Epoch 924/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.2868e-05 - val_loss: 2.0257e-05
# Epoch 925/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.0595e-05 - val_loss: 1.9722e-05
# Epoch 926/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.8868e-05 - val_loss: 3.2871e-05
# Epoch 927/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.6297e-05 - val_loss: 2.9426e-05
# Epoch 928/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.9840e-05 - val_loss: 2.6155e-05
# Epoch 929/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.5984e-05 - val_loss: 3.7935e-05
# Epoch 930/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.5438e-05 - val_loss: 3.3692e-05
# Epoch 931/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.5558e-05 - val_loss: 2.3650e-05
# Epoch 932/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.6156e-05 - val_loss: 1.6760e-05
# Epoch 933/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.6173e-05 - val_loss: 1.1447e-05
# Epoch 934/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.4796e-05 - val_loss: 1.0569e-05
# Epoch 935/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.2231e-05 - val_loss: 1.0554e-05
# Epoch 936/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0407e-05 - val_loss: 9.6782e-06
# Epoch 937/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0853e-05 - val_loss: 8.7578e-06
# Epoch 938/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0391e-05 - val_loss: 8.4674e-06
# Epoch 939/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.6773e-06 - val_loss: 7.8731e-06
# Epoch 940/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.0271e-05 - val_loss: 7.6950e-06
# Epoch 941/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.2463e-06 - val_loss: 7.1439e-06
# Epoch 942/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.0351e-06 - val_loss: 6.7403e-06
# Epoch 943/1000
# 7/7 [==============================] - 12s 2s/step - loss: 6.9510e-06 - val_loss: 7.1791e-06
# Epoch 944/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.6346e-06 - val_loss: 6.6555e-06
# Epoch 945/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.1122e-06 - val_loss: 6.7480e-06
# Epoch 946/1000
# 7/7 [==============================] - 12s 2s/step - loss: 6.9943e-06 - val_loss: 7.5724e-06
# Epoch 947/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.1837e-06 - val_loss: 7.8133e-06
# Epoch 948/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.6928e-06 - val_loss: 6.4768e-06
# Epoch 949/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.6401e-06 - val_loss: 6.1419e-06
# Epoch 950/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.6429e-06 - val_loss: 6.7497e-06
# Epoch 951/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.6691e-06 - val_loss: 7.1830e-06
# Epoch 952/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.0323e-06 - val_loss: 8.4304e-06
# Epoch 953/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.1239e-05 - val_loss: 8.2735e-06
# Epoch 954/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.2818e-05 - val_loss: 9.5445e-06
# Epoch 955/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.8146e-05 - val_loss: 1.1231e-05
# Epoch 956/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.6347e-05 - val_loss: 1.5624e-05
# Epoch 957/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.5727e-05 - val_loss: 1.5266e-05
# Epoch 958/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.1509e-05 - val_loss: 1.7104e-05
# Epoch 959/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.7445e-05 - val_loss: 2.8426e-05
# Epoch 960/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.5694e-05 - val_loss: 2.6553e-05
# Epoch 961/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.4940e-05 - val_loss: 2.8753e-05
# Epoch 962/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.3728e-05 - val_loss: 2.3463e-05
# Epoch 963/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.0890e-05 - val_loss: 3.1125e-05
# Epoch 964/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.1297e-05 - val_loss: 6.0695e-05
# Epoch 965/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.7711e-05 - val_loss: 7.7229e-05
# Epoch 966/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.2112e-04 - val_loss: 5.9659e-05
# Epoch 967/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.8835e-05 - val_loss: 4.5416e-05
# Epoch 968/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.0607e-05 - val_loss: 4.5354e-05
# Epoch 969/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.1410e-05 - val_loss: 7.1028e-05
# Epoch 970/1000
# 7/7 [==============================] - 12s 2s/step - loss: 8.5402e-05 - val_loss: 4.4439e-05
# Epoch 971/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.4059e-05 - val_loss: 3.8353e-05
# Epoch 972/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.3176e-05 - val_loss: 3.4860e-05
# Epoch 973/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.8778e-05 - val_loss: 4.9889e-05
# Epoch 974/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.1552e-05 - val_loss: 4.6293e-05
# Epoch 975/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.6387e-05 - val_loss: 3.3848e-05
# Epoch 976/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.4085e-05 - val_loss: 3.0445e-05
# Epoch 977/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.8078e-05 - val_loss: 2.6068e-05
# Epoch 978/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.2553e-05 - val_loss: 1.8523e-05
# Epoch 979/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.8063e-05 - val_loss: 2.2367e-05
# Epoch 980/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.7528e-05 - val_loss: 3.0631e-05
# Epoch 981/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.9737e-05 - val_loss: 1.4086e-05
# Epoch 982/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.2451e-05 - val_loss: 1.5444e-05
# Epoch 983/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.9543e-05 - val_loss: 1.7248e-05
# Epoch 984/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.6491e-05 - val_loss: 3.0304e-05
# Epoch 985/1000
# 7/7 [==============================] - 12s 2s/step - loss: 4.0367e-05 - val_loss: 2.1243e-05
# Epoch 986/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.4686e-05 - val_loss: 1.9305e-05
# Epoch 987/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.0674e-05 - val_loss: 1.5928e-05
# Epoch 988/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.6025e-05 - val_loss: 1.4299e-05
# Epoch 989/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.7249e-05 - val_loss: 1.5564e-05
# Epoch 990/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.0390e-05 - val_loss: 1.4007e-05
# Epoch 991/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.0544e-05 - val_loss: 1.4661e-05
# Epoch 992/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.8499e-05 - val_loss: 1.6957e-05
# Epoch 993/1000
# 7/7 [==============================] - 12s 2s/step - loss: 2.3009e-05 - val_loss: 1.6765e-05
# Epoch 994/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.0130e-05 - val_loss: 2.7428e-05
# Epoch 995/1000
# 7/7 [==============================] - 12s 2s/step - loss: 3.9579e-05 - val_loss: 4.8498e-05
# Epoch 996/1000
# 7/7 [==============================] - 12s 2s/step - loss: 5.6206e-05 - val_loss: 1.1661e-04
# Epoch 997/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.3238e-04 - val_loss: 7.8514e-05
# Epoch 998/1000
# 7/7 [==============================] - 12s 2s/step - loss: 9.4095e-05 - val_loss: 5.1900e-05
# Epoch 999/1000
# 7/7 [==============================] - 12s 2s/step - loss: 7.8426e-05 - val_loss: 5.5018e-05
# Epoch 1000/1000
# 7/7 [==============================] - 12s 2s/step - loss: 1.4598e-04 - val_loss: 6.2480e-05

# %% [markdown]
# ### 显示训练结果

# %%
sample_val_images, sample_val_keypoints = next(iter(train_dataset))
sample_val_images = sample_val_images[:2]
sample_val_keypoints = sample_val_keypoints[:4].reshape(-1, 4, 2) * IMG_SIZE
predictions = model.predict(sample_val_images).reshape(-1, 4, 2) * IMG_SIZE
 
print("实际")
visualize_keypoints(sample_val_images, sample_val_keypoints)

print("模型预测")
visualize_keypoints(sample_val_images, predictions)
# Out:
# 实际
# 模型预测
